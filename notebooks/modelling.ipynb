# %%
import pandas as pd 
import numpy as np 
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.metrics import root_mean_squared_error
import mlflow
import xgboost as xgb
#from hyperopt import tpe, hp, STATUS_OK, fmin, Trials
#from hyperopt.pyll import scope

# %%
mlflow.set_experiment('road_risk')
# Out:
# <Experiment: artifact_location='file:///C:/Users/cathy/Documents/Aravind_senpai/Road_risk_preds/road_risk/notebooks/mlruns/114172339510252089', creation_time=1761178122904, experiment_id='114172339510252089', last_update_time=1761178122904, lifecycle_stage='active', name='road_risk', tags={}>

# %%
mlflow.get_tracking_uri()
# Out:
# 'file:///C:/Users/cathy/Documents/Aravind_senpai/Road_risk_preds/road_risk/notebooks/mlruns'

# %%
df = pd.read_csv('../data/train.csv')

# %%
df = df.drop(['id'], axis = 1)

# %%
df.sample()
# Out:
#        road_type  num_lanes  curvature  speed_limit  lighting weather  \
# 299619   highway          2       0.65           45  daylight   foggy
#
#         road_signs_present  public_road time_of_day  holiday  school_season  \
# 299619               False        False     evening    False          False
#
#         num_reported_accidents  accident_risk
# 299619                       1           0.28

# %%
x = df.drop(['accident_risk'], axis = 1)
y = df['accident_risk'].values

# %%
x_train, x_val, y_train, y_val= train_test_split(x,y,train_size = 0.8, random_state = 42)

# %%
num_cols = df.select_dtypes(['int', 'float']).columns.to_list()
cat_cols = df.select_dtypes(['object', 'bool']).columns.to_list()

num_cols.remove('accident_risk')
print(num_cols)
# Out:
# ['num_lanes', 'curvature', 'speed_limit', 'num_reported_accidents']

# %%
dv = DictVectorizer(sparse = False)

train_dict = x_train[cat_cols + num_cols].to_dict(orient = 'records')
x_train_encoded = dv.fit_transform(train_dict)

val_dict = x_val[cat_cols + num_cols].to_dict(orient = 'records')
x_val_encoded = dv.transform(val_dict)

# %%
with mlflow.start_run():
    mlflow.set_tag("model", "linear_regression")
    lr = LinearRegression()
    lr.fit(x_train_encoded, y_train)
    y_pred = lr.predict(x_val_encoded)
    rmse = root_mean_squared_error(y_val, y_pred)
    print(rmse)
    mlflow.log_metric("rmse", rmse)
# Out:
# 0.07353086258983142

# %%
with mlflow.start_run():
    mlflow.set_tag("model", "Lasso")
    alpha = 1
    mlflow.log_param("alpha", alpha)
    lasso = Lasso(alpha = alpha)
    lasso.fit(x_train_encoded, y_train)
    y_pred = lasso.predict(x_val_encoded)
    rmse = root_mean_squared_error(y_val, y_pred)
    print(rmse)
    mlflow.log_metric("rmse", rmse)
# Out:
# 0.1627118768942706

# %%
with mlflow.start_run():
    mlflow.set_tag("model", "Ridge")
    ridge = Ridge(alpha = 0.001)
    ridge.fit(x_train_encoded, y_train)
    y_pred = ridge.predict(x_val_encoded)
    rmse = root_mean_squared_error(y_val, y_pred)
    print(rmse)
    mlflow.log_metric("rmse", rmse)
# Out:
# 0.07353086258195071

# %%
train = xgb.DMatrix(x_train_encoded, label = y_train)
valid = xgb.DMatrix(x_val_encoded, y_val)

# %%
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", 'xgboost')
        mlflow.log_params(params)
        booster = xgb.train(
            params = params, 
            dtrain = train, 
            num_boost_round = 200, 
            evals=[(train, "train"), (valid, "validation")],
            early_stopping_rounds = 50,
            verbose_eval = False
        )
        y_pred = booster.predict(valid)
        rmse = root_mean_squared_error(y_val, y_pred)
        mlflow.log_metric("rmse", rmse)
        mlflow.xgboost.log_model(booster, name = "xgb_mlflow")
        return {'loss': rmse, 'status': STATUS_OK}

# %%
search_space = {
    'max_depth' : scope.int(hp.quniform("max_depth", 10,30,1)),
    'learning_rate' : hp.loguniform("learning_rate", -3, 0),
    'min_child_weight' : hp.choice("min_samples_split", [2,5,7,10]),
    'subsample' : hp.uniform("subsample", 0.7,1),
    'colsample_bytree' : hp.uniform("colsample_bytree", 0.7,1),
    'gamma' : hp.uniform("gamma", 0, 0.5),
    'reg_alpha' : hp.loguniform("reg_alpha", -5, 0),
    "reg_lambda" : hp.loguniform("reg_lambda", -5,0),
    'objective' : 'reg:squarederror'

}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 2
#       1 search_space = {
# ----> 2     'max_depth' : scope.int(hp.quniform("max_depth", 10,30,1)),
#       3     'learning_rate' : hp.loguniform("learning_rate", -3, 0),
#       4     'min_child_weight' : hp.choice("min_samples_split", [2,5,7,10]),
#       5     'subsample' : hp.uniform("subsample", 0.7,1),
#       6     'colsample_bytree' : hp.uniform("colsample_bytree", 0.7,1),
#       7     'gamma' : hp.uniform("gamma", 0, 0.5),
#       8     'reg_alpha' : hp.loguniform("reg_alpha", -5, 0),
#       9     "reg_lambda" : hp.loguniform("reg_lambda", -5,0),
#      10     'objective' : 'reg:squarederror'
#      11
#      12 }
#
# NameError: name 'scope' is not defined

# %%
trials = Trials()
best_result = fmin(
    fn = objective, 
    space = search_space, 
    algo = tpe.suggest, 
    max_evals = 50
)
